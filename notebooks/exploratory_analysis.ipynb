# %% [markdown]
# # Odyssey Exploratory Analysis
#
# This notebook is optional and only reads generated outputs. The main code path lives in `src/` and `scripts/`.

# %%
from pathlib import Path
import pandas as pd

tables = sorted(Path('../outputs/tables').glob('*.csv'))
tables[:5]
